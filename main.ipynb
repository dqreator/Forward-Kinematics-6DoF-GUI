# %%
import os
import sys
import numpy as np 
from pathlib import Path

# The nex lines are only for jupyter
curr_dir = os.path.abspath('')
module_dir = curr_dir+'/src'
sys.path.insert(0, str(module_dir))

from geolib import * 

j = dh_parse(0,0,0,0,0,0)
m = kinematics(j)
ee,u,v,w = xyz_pos(m)
P = draw_robot(ee,u,v,w)
